# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar dataset
df = pd.read_csv("taxis.csv")

# Vista rápida
df.head()
# Out:
#    VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  passenger_count  \
# 0         1  01/01/2020 12:28:15 AM  01/01/2020 12:33:03 AM                1
# 1         1  01/01/2020 12:35:39 AM  01/01/2020 12:43:04 AM                1
# 2         1  01/01/2020 12:47:41 AM  01/01/2020 12:53:52 AM                1
# 3         1  01/01/2020 12:55:23 AM  01/01/2020 01:00:14 AM                1
# 4         2  01/01/2020 12:01:58 AM  01/01/2020 12:04:16 AM                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.2           1                  N           238           239
# 1            1.2           1                  N           239           238
# 2            0.6           1                  N           238           238
# 3            0.8           1                  N           238           151
# 4            0.0           1                  N           193           193
#
# ...

# %%
# Información general
df.info()

# Nulos por columna
print(df.isnull().sum())

# Estadísticas básicas
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               999 non-null    int64
#  1   tpep_pickup_datetime   999 non-null    object
#  2   tpep_dropoff_datetime  999 non-null    object
#  3   passenger_count        999 non-null    int64
#  4   trip_distance          999 non-null    float64
#  5   RatecodeID             999 non-null    int64
#  6   store_and_fwd_flag     999 non-null    object
#  7   PULocationID           999 non-null    int64
#  8   DOLocationID           999 non-null    int64
#  9   payment_type           999 non-null    int64
#  10  fare_amount            999 non-null    float64
#  11  extra                  999 non-null    float64
#  12  mta_tax                999 non-null    float64
#  13  tip_amount             999 non-null    float64
# ...

# %%
df["tpep_pickup_datetime"] = pd.to_datetime(df["tpep_pickup_datetime"])
df["tpep_dropoff_datetime"] = pd.to_datetime(df["tpep_dropoff_datetime"])
# Out:
# /tmp/ipykernel_96/3083108826.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["tpep_pickup_datetime"] = pd.to_datetime(df["tpep_pickup_datetime"])
# /tmp/ipykernel_96/3083108826.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["tpep_dropoff_datetime"] = pd.to_datetime(df["tpep_dropoff_datetime"])

# %%
df["trip_duration_min"] = (df["tpep_dropoff_datetime"] - df["tpep_pickup_datetime"]).dt.total_seconds() / 60

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2020-01-01 00:28:15   2020-01-01 00:33:03                1
# 1         1  2020-01-01 00:35:39   2020-01-01 00:43:04                1
# 2         1  2020-01-01 00:47:41   2020-01-01 00:53:52                1
# 3         1  2020-01-01 00:55:23   2020-01-01 01:00:14                1
# 4         2  2020-01-01 00:01:58   2020-01-01 00:04:16                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.2           1                  N           238           239
# 1            1.2           1                  N           239           238
# 2            0.6           1                  N           238           238
# 3            0.8           1                  N           238           151
# 4            0.0           1                  N           193           193
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df = df[(df["trip_distance"] > 0) & 
        (df["total_amount"] > 0) & 
        (df["trip_duration_min"] > 0)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 983 entries, 0 to 998
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               983 non-null    int64
#  1   tpep_pickup_datetime   983 non-null    datetime64[ns]
#  2   tpep_dropoff_datetime  983 non-null    datetime64[ns]
#  3   passenger_count        983 non-null    int64
#  4   trip_distance          983 non-null    float64
#  5   RatecodeID             983 non-null    int64
#  6   store_and_fwd_flag     983 non-null    object
#  7   PULocationID           983 non-null    int64
#  8   DOLocationID           983 non-null    int64
#  9   payment_type           983 non-null    int64
#  10  fare_amount            983 non-null    float64
#  11  extra                  983 non-null    float64
#  12  mta_tax                983 non-null    float64
#  13  tip_amount             983 non-null    float64
# ...

# %%
print("Tamaño final del dataset:", df.shape)
print("Duración media del viaje (min):", df["trip_duration_min"].mean())
print("Distancia media (millas):", df["trip_distance"].mean())
print("Importe medio ($):", df["total_amount"].mean())
# Out:
# Tamaño final del dataset: (983, 19)
# Duración media del viaje (min): 14.088097660223804
# Distancia media (millas): 2.845127161749746
# Importe medio ($): 18.54163784333673

# %%
df['store_and_fwd_flag'] = df['store_and_fwd_flag'].map({'N':0, 'Y':1})

# %%
df.head(
)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2020-01-01 00:28:15   2020-01-01 00:33:03                1
# 1         1  2020-01-01 00:35:39   2020-01-01 00:43:04                1
# 2         1  2020-01-01 00:47:41   2020-01-01 00:53:52                1
# 3         1  2020-01-01 00:55:23   2020-01-01 01:00:14                1
# 5         2  2020-01-01 00:09:44   2020-01-01 00:10:37                1
#
#    trip_distance  RatecodeID  store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.20           1                   0           238           239
# 1           1.20           1                   0           239           238
# 2           0.60           1                   0           238           238
# 3           0.80           1                   0           238           151
# 5           0.03           1                   0             7           193
#
# ...

# %%
import matplotlib.pyplot as plt

# --- 1. Histograma de distancias ---
plt.figure(figsize=(8,5))
df["trip_distance"].plot.hist(bins=40, alpha=0.7)
plt.xlabel("Distancia (millas)")
plt.ylabel("Número de viajes")
plt.title("Distribución de distancias de viaje (millas)")
plt.show()


# --- 2. Histograma de duraciones ---
plt.figure(figsize=(8,5))
df["trip_duration_min"].plot.hist(bins=40, alpha=0.7, color="orange")
plt.xlabel("Duración (minutos)")
plt.ylabel("Número de viajes")
plt.title("Distribución de duraciones de viaje (min)")
plt.show()


# --- 3. Relación distancia vs importe total ---
plt.figure(figsize=(8,5))
plt.scatter(df["trip_distance"], df["total_amount"], alpha=0.5, s=10)
plt.xlabel("Distancia (millas)")
plt.ylabel("Importe total ($)")
plt.title("Distancia vs Importe Total")
plt.show()
